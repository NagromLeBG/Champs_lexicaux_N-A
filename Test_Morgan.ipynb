# %%
import pandas as pd
import matplotlib.pyplot as plt
import spacy
import gensim
from pathlib import Path
import sklearn
# Out:
# Les cellules en cours d’exécution avec .venv (Python 3.12.13) nécessitent le package ipykernel.
#
# Installez « ipykernel » dans l’environnement Python.
#
# Commande : « /Users/morganr/Champs_lexicaux_N-A/.venv/bin/python -m pip install ipykernel -U --force-reinstall »

# %%
dossier_path = Path("/Users/morganrichard/Desktop/Test_Champs_lexcaux/Corpus_textes")

donnees = []

# On boucle sur tous les fichiers .txt du dossier
for fichier in dossier_path.glob("*.txt"):
    with open(fichier, "r", encoding="utf-8") as f:
        contenu = f.read()
        
        # On détermine le label selon le nom du fichier
        label = "naturaliste" if "_N" in fichier.name else "non-naturaliste"
        
        donnees.append({
            "nom_fichier": fichier.name,
            "texte_brut": contenu,
            "label": label
        })

# Création du tableau de bord (DataFrame)
df = pd.DataFrame(donnees)
print(f"{len(df)} textes chargés avec succès.")
# Out:
# 10 textes chargés avec succès.

# %%
df.head(10)
# Out:
#                                          nom_fichier  \
# 0            1883_Lesueur_L'amant-de-Genevieve_A.txt
# 1       1882_Albalat_L'inassouvie-roman-intime_A.txt
# 2             1882_Verne_L-Ecole-des-Robinsons_A.txt
# 3                        1885_Adam_Chair-molle_N.txt
# 4                         1886_Rosny_Nell-Horn_N.txt
# 5                 1884_Rachilde_Monsieur-Venus_A.txt
# 6           1879_ Goncourt_Les-Freres-Zemganno_N.txt
# 7                       1881_Lemmonier_un-mâle_N.txt
# 8  1881_Barbey-d-Aurevilly_Une-histoire-sans-nom_...
# 9                      1882_Cladel_Ompdrailles_N.txt
#
#                                           texte_brut            label
# 0  PREMIÈRE PARTIE Chapitre I. Il y avait bien tr...  non-naturaliste
# 1  \nLES CHASTETÉS IMPURESPREMIERE PARTIEI.\nJe n...  non-naturaliste
# 2  I« Île à vendre, au comptant, frais en sus, au...  non-naturaliste
# 3  \n\n\nPaul Adam\n\n\n\nChair molle\n\n\nRoman ...      naturaliste
# 4  \n\n\n\n\nPREMIÈRE PARTIE\nAu fond de la pelou...      naturaliste
# 5  RACHILDE  MONSIEUR VÉNUS  A Monsieur LÉO D'ORF...  non-naturaliste
# 6  \n\n\n\nEdmond de Goncourt\n\n\n\nLes Frères Z...      naturaliste
# 7  \n\nCamille Lemonnier\n\n\n\n\nUn mâle\n\n\n\n...      naturaliste
# 8  Mon cher Paul Bourget,  Je veux mettre votre n...  non-naturaliste
# 9  \nLéon Cladel.\n\nOmpdrailles le Tombeau-des-L...      naturaliste

# %%
# On reprend la fonction de l'étape précédente

nlp = spacy.load("fr_core_news_md")
def preprocess_text(text):
    doc = nlp(text.lower())
    tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]
    return " ".join(tokens)

# Application magique de Pandas : on nettoie les 10 textes d'un coup
df['texte_propre'] = df['texte_brut'].apply(preprocess_text)
 
# Regardons le résultat
print(df[['label', 'texte_propre']].head())
# Out:
#              label                                       texte_propre
# 0  non-naturaliste  partie chapitre bien minute maire achever disc...
# 1  non-naturaliste  chasteté impurespremier partiei savoir aimer é...
# 2  non-naturaliste  île vendre comptant frais sus offrir dernier e...
# 3      naturaliste  paul adam chair mou roman naturaliste partie g...
# 4      naturaliste  partie fond pelouse lisière massif sombre tota...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import LatentDirichletAllocation

# --- 1. PREPROCESSING ---
# (On utilise la fonction preprocess_text définie précédemment avec SpaCy)
df['texte_propre'] = df['texte_brut'].apply(preprocess_text)

# --- 2. VECTORISATION (TF-IDF) ---
vectorizer = TfidfVectorizer(max_features=50, min_df=2) # On garde les 50 mots les plus importants
tfidf_matrix = vectorizer.fit_transform(df['texte_propre'])

# --- 3. CLUSTERING (K-Means) ---
# On demande à l'algo de créer 2 groupes (puisqu'on sait qu'on a 2 types de textes)
kmeans = KMeans(n_clusters=2, random_state=42)
df['cluster'] = kmeans.fit_predict(tfidf_matrix)

# --- 4. TOPIC MODELING (LDA) ---
# On cherche à extraire 2 thèmes majeurs du corpus
lda = LatentDirichletAllocation(n_components=2, random_state=42)
lda.fit(tfidf_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
# Tableau croisé pour comparer les vrais labels et les clusters trouvés
comparaison = pd.crosstab(df['label'], df['cluster'])
print("--- Comparaison Vrai Label vs Cluster ---")
print(comparaison)
# Out:
# --- Comparaison Vrai Label vs Cluster ---
# cluster          0  1
# label
# naturaliste      2  3
# non-naturaliste  5  0

# %%
def afficher_topics(model, vectorizer, n_top_words):
    mots = vectorizer.get_feature_names_out()
    for topic_idx, topic in enumerate(model.components_):
        message = f"Thème #{topic_idx} : "
        message += " | ".join([mots[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)

# On affiche les 10 mots principaux pour nos 2 topics
afficher_topics(lda, vectorizer, 10)
# Out:
# Thème #0 : être | bien | faire | avoir | vouloir | voir | venir | aller | jour | grand
# Thème #1 : faire | être | bien | avoir | voir | petit | vouloir | aller | venir | jour

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# On calcule les distances entre les textes
distances = linkage(tfidf_matrix.toarray(), method='ward')

plt.figure(figsize=(10, 7))
plt.title("Regroupement hiérarchique des textes (Dendrogramme)")
dendrogram(distances, labels=df['nom_fichier'].values, leaf_rotation=90)
plt.show()

# %%
# On cherche les textes qui sont étiquetés 'naturaliste' mais classés en 'cluster 0'
infiltres = df[(df['label'] == 'naturaliste') & (df['cluster'] == 0)]
print("Les 2 textes naturalistes qui ressemblent aux non-naturalistes sont :")
print(infiltres['nom_fichier'])
# Out:
# Les 2 textes naturalistes qui ressemblent aux non-naturalistes sont :
# 3      1885_Adam_Chair-molle_N.txt
# 9    1882_Cladel_Ompdrailles_N.txt
# Name: nom_fichier, dtype: str

# %%
import numpy as np

# On calcule la moyenne des scores TF-IDF par cluster
cluster_centers = []
for i in range(2):
    masque_cluster = (df['cluster'].to_numpy() == i)  # masque NumPy (compatible SciPy sparse)
    cluster_centers.append(tfidf_matrix[masque_cluster].mean(axis=0))

mots = vectorizer.get_feature_names_out()

for i, center in enumerate(cluster_centers):
    # On transforme la matrice en tableau plat et on récupère les indices des 10 meilleurs mots
    indices = np.argsort(np.asarray(center).flatten())[::-1][:10]
    print(f"\nTop 10 mots du Cluster {i} :")
    print([mots[idx] for idx in indices])
# Out:
# Top 10 mots du Cluster 0 :
# ['être', 'faire', 'bien', 'avoir', 'voir', 'vouloir', 'aller', 'venir', 'savoir', 'jour']
#
# Top 10 mots du Cluster 1 :
# ['petit', 'faire', 'être', 'voir', 'bien', 'jour', 'main', 'homme', 'grand', 'avoir']

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# On calcule les liens entre les textes
Z = linkage(tfidf_matrix.toarray(), method='ward')

plt.figure(figsize=(12, 8))
plt.title("Hiérarchie de ressemblance des textes")
dendrogram(Z, labels=df['nom_fichier'].values, leaf_rotation=90)
plt.axhline(y=1.2, color='r', linestyle='--') # Ligne de coupe suggérée
plt.show()
